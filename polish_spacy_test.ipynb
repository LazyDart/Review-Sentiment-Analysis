# %%
import spacy
import numpy as np
import pandas as pd
import gensim

# %%
nlp = spacy.load("pl_core_news_lg")

# %%
# With something like that, next we get maxpool and average of all values. And we input it into LSTM.
[token.vector for token in doc]
# Out:
# [array([-6.4873e-01,  1.4850e+00, -1.6393e+00, -3.2994e+00,  7.4470e-01,
#          6.8984e-01, -2.1834e+00, -8.5327e-02,  1.2072e+00, -2.1965e+00,
#          1.0865e+00,  3.9058e-01, -9.8522e-01,  4.5014e-01, -7.3516e-01,
#         -4.3904e-01,  3.8784e+00, -3.9709e-01,  1.4673e+00,  2.7598e+00,
#          1.4190e+00, -5.1024e-01,  3.4526e+00, -1.2671e+00, -4.5721e+00,
#          4.8127e-01,  3.1109e+00,  1.0515e+00, -4.5329e-01, -1.9196e+00,
#          7.0116e-01, -2.9600e+00,  1.1990e+00,  1.3863e+00,  2.5252e+00,
#         -1.2384e+00, -6.7671e-01, -6.6369e-01,  1.1920e+00, -2.2995e+00,
#         -6.1579e-01, -1.8278e+00,  2.8715e-01, -5.8929e-01,  1.4640e-01,
#         -6.1125e-03,  6.0753e-01, -1.0369e+00,  4.0196e+00, -1.2043e+00,
#         -1.3542e+00, -1.0275e-03,  8.8565e-01, -1.9811e+00,  1.2451e+00,
#          1.5784e+00,  3.7275e-02, -2.3948e+00,  1.5005e+00, -2.0428e+00,
#         -5.3577e-01,  1.0350e+00,  1.3840e+00, -2.1033e+00,  1.4462e-01,
# ...

# %%
model_file_path = './gensim models/cbow.v300.m8.hs.mwe.w2v.gensim'

# %%
model = gensim.models.KeyedVectors.load(model_file_path)

# %%
model.get_vector("w")
# Out:
# array([-6.33020e-02, -2.05720e-02, -3.30970e-02,  5.21530e-02,
#         4.94250e-02, -1.07668e-01,  5.18230e-02,  6.01980e-02,
#        -9.67750e-02, -5.75040e-02, -5.36230e-02,  5.81910e-02,
#         3.95720e-02, -2.23710e-02,  2.41000e-03, -7.58170e-02,
#         8.33350e-02, -2.02510e-02, -2.25340e-02, -2.74400e-02,
#        -8.39470e-02, -5.93510e-02, -3.52240e-02, -1.20000e-05,
#         5.38470e-02,  9.20560e-02,  7.41220e-02,  6.43950e-02,
#        -2.47410e-02,  5.16160e-02,  2.97780e-02,  7.12000e-04,
#        -6.41260e-02, -1.29010e-02,  1.16964e-01, -2.27130e-02,
#         7.49120e-02,  5.54630e-02, -4.22810e-02, -7.73110e-02,
#        -7.94630e-02,  2.98070e-02,  7.78400e-03,  1.66242e-01,
#        -1.12690e-02,  2.48290e-02,  3.39490e-02, -2.75310e-02,
#        -7.10100e-03, -8.99390e-02,  2.52260e-02, -1.00439e-01,
#        -2.56560e-02, -8.35030e-02, -4.52450e-02,  1.68400e-03,
#        -9.66240e-02, -1.21890e-02, -3.66210e-02,  3.05640e-02,
# ...
